# %% [markdown]
# Dataset link : https://www.kaggle.com/datasets/uciml/human-activity-recognition-with-smartphones

# %%
# Import the panda library
import pandas as pd

# %% [markdown]
# ## 1. Import the Dataset

# %%
# Reading the datasets from the CSV files
training_data = pd.read_csv("train.csv")
data_test  = pd.read_csv("test.csv")

# %% [markdown]
# ## 2. Display Top 5 Rows of The Dataset

# %%
# It display the first five rows
training_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %% [markdown]
# ## 3. Check Last 5 Rows of The Dataset

# %%
# IT Display the last five rows
training_data.tail()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 7347         -0.195387          0.039905          0.077078         -0.282301
# 7348         -0.235309          0.004816          0.059280         -0.322552
# 7349         -0.218218         -0.103822          0.274533         -0.304515
# 7350         -0.219139         -0.111412          0.268893         -0.310487
# 7351         -0.269270         -0.087212          0.177404         -0.377404
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# ...

# %% [markdown]
# ## 4. Find Shape

# %%
# Get the Dimensions 
training_data.shape
# Out:
# (7352, 563)

# %%
# Print the number of rows and column
print("Number of Rows",training_data.shape[0])
print("Number of columns",training_data.shape[1])
# Out:
# Number of Rows 7352
# Number of columns 563

# %% [markdown]
# ## 5. Remove the Duplicate Values

# %%
# Check the duplicate rows
training_data.duplicated().any()
# Out:
# False

# %%
# find the duplicate column and Transpos the DataFrame and check again for duplicate rows
duplicated_columns = training_data.columns[training_data.T.duplicated()].tolist()

# %%
# length of the duplicat column
len(duplicated_columns)
# Out:
# 21

# %%
# Drop the duplicate columns
training_data = training_data.drop(duplicated_columns,axis=1)

# %%
# Again Get the dimensions from the training dataset
training_data.shape
# Out:
# (7352, 542)

# %% [markdown]
# ## 6. Handel the Missing Values

# %%
# Check missing values 
training_data.isnull().sum()
# Out:
# tBodyAcc-mean()-X       0
# tBodyAcc-mean()-Y       0
# tBodyAcc-mean()-Z       0
# tBodyAcc-std()-X        0
# tBodyAcc-std()-Y        0
#                        ..
# angle(X,gravityMean)    0
# angle(Y,gravityMean)    0
# angle(Z,gravityMean)    0
# subject                 0
# Activity                0
# Length: 542, dtype: int64

# %%
# import the libraries for the visualization or graph
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plot the count plot to visualize the distribution of values
sns.countplot(x=training_data['Activity'])
# Rotate the x-axis labels by 35 degrees
plt.xticks(rotation=35)
# Display the plot
plt.show()

# %% [markdown]
# ## 7. Store the Feature Matrix

# %%
# Split the dataset into features 'x' and target variable 'y', with the 'Activity'
X = training_data.drop('Activity',axis=1)
y = training_data['Activity']

# %%
y
# Out:
# 0               STANDING
# 1               STANDING
# 2               STANDING
# 3               STANDING
# 4               STANDING
#               ...
# 7347    WALKING_UPSTAIRS
# 7348    WALKING_UPSTAIRS
# 7349    WALKING_UPSTAIRS
# 7350    WALKING_UPSTAIRS
# 7351    WALKING_UPSTAIRS
# Name: Activity, Length: 7352, dtype: object

# %%
# Import the LabelEncoder from the sklearn.preprocessing
from sklearn.preprocessing import LabelEncoder
# Create the variable of the  LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)
y
# Out:
# array([2, 2, 2, ..., 5, 5, 5])

# %% [markdown]
# ## 8. Split The Dataset

# %%
# Import the train_test_split function from the sklearn.model_selection to split the data
from sklearn.model_selection import train_test_split

# %%
# Split the dataset into training and testing sets 80% for training and 20% for testing
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20, random_state=42)

# %% [markdown]
# ## 9. Logistic Regression

# %%
# import the libraries
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Create variable for the LogisticRegression model with 500 iterations
log = LogisticRegression(max_iter=500)
# Train the model 
log.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
# Predict the target values for the test dataset
y_pred1 = log.predict(X_test)
# Calculate the accuracy score
accuracy_score(y_test,y_pred1)
# Out:
# 0.981645139360979

# %% [markdown]
# ## 10. Random Forest Classifier

# %%
# Import the Random Forest Classifier from sklearn.ensemble
from sklearn.ensemble import RandomForestClassifier
# Create the variable for RandomForestClassifier
RF = RandomForestClassifier()
# Train the random forest model on the dataset
RF.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
# again Predict the target values for the test dataset
y_pred2 = RF.predict(X_test)
# Calculate the accuracy score
accuracy_score(y_test,y_pred2)
# Out:
# 0.9796057104010877

# %% [markdown]
# ## 11. Feature Selection

# %% [markdown]
# ###  Filter Method

# %%
# Import SelectKBest and f_classif from sklearn.feature_selection
from sklearn.feature_selection import SelectKBest,f_classif

# %%
# Set the number k=200
k=200

# Initialize feature selector
selector = SelectKBest(f_classif,k=k)

# Feature selector to fit on the training data
X_train_selected = selector.fit_transform(X_train,y_train)

# Transform the test dataset
X_test_selected = selector.transform(X_test)

# Get the indices from the selected features
selected_indices=selector.get_support(indices=True)
selected_features = X_train.columns[selected_indices]

# Print the length of selected features
print(len(selected_features))
# Out:
# 200

# %% [markdown]
# ### Wrapper Method

# %%
# Import Recursive Feature Elimination (RFE) from sklearn.feature_selection
from sklearn.feature_selection import RFE
# Import RandomForestClassifier from sklearn.ensemble
from sklearn.ensemble import RandomForestClassifier

# %%
estimator = RandomForestClassifier()

# %%
# Set the number k=100 for RFE
k=100
rfe_selector = RFE(estimator,n_features_to_select=k)

# Transform the train and test dataset to keep the selected features after RFE
X_train_selected_rfe = rfe_selector.fit_transform(X_train_selected,y_train)
X_test_selected_rfe = rfe_selector.transform(X_test_selected)

# Get the indices from the selected features
selected_indices_rfe = rfe_selector.get_support(indices=True)

# Get the name from selected features by indices
selected_features_rfe = selected_features[selected_indices_rfe]
print(selected_features_rfe)
# Out:
# Index(['tBodyAcc-std()-X', 'tBodyAcc-mad()-X', 'tBodyAcc-max()-X',
#        'tBodyAcc-energy()-X', 'tBodyAcc-iqr()-X', 'tBodyAcc-entropy()-X',
#        'tGravityAcc-mean()-X', 'tGravityAcc-mean()-Y', 'tGravityAcc-max()-X',
#        'tGravityAcc-max()-Y', 'tGravityAcc-min()-X', 'tGravityAcc-min()-Y',
#        'tGravityAcc-energy()-X', 'tGravityAcc-energy()-Y',
#        'tBodyAccJerk-std()-X', 'tBodyAccJerk-std()-Y', 'tBodyAccJerk-std()-Z',
#        'tBodyAccJerk-mad()-X', 'tBodyAccJerk-mad()-Z', 'tBodyAccJerk-max()-X',
#        'tBodyAccJerk-max()-Y', 'tBodyAccJerk-max()-Z', 'tBodyAccJerk-sma()',
#        'tBodyAccJerk-energy()-X', 'tBodyAccJerk-energy()-Y',
#        'tBodyAccJerk-iqr()-X', 'tBodyAccJerk-entropy()-X', 'tBodyGyro-std()-X',
#        'tBodyGyro-std()-Y', 'tBodyGyro-std()-Z', 'tBodyGyro-mad()-X',
#        'tBodyGyro-mad()-Y', 'tBodyGyro-mad()-Z', 'tBodyGyro-max()-X',
#        'tBodyGyro-min()-X', 'tBodyGyro-iqr()-X', 'tBodyGyro-iqr()-Y',
# ...

# %%
# Print the length 
print(len(selected_features_rfe))
# Out:
# 100

# %%
RF = RandomForestClassifier()

# %%
# Fit the RF model
RF.fit(X_train_selected_rfe,y_train)
# Out:
# RandomForestClassifier()

# %%
# Predict the target values
y_pred_rf = RF.predict(X_test_selected_rfe)

# %%
# Import the accuracy_score from sklearn.metrics
from sklearn.metrics import accuracy_score

# %%
# Calculate the accuracy score
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.9748470428280082

# %%
import joblib

# %%
# Save the Random Forest model as "model_rfe"
joblib.dump(RF,"model_rfe")
# Out:
# ['model_rfe']

# %%
joblib.dump(selector,"Top K selector")
# Out:
# ['Top K selector']

# %%
# Save the RFE selector as "Feature Selector"
joblib.dump(rfe_selector,"Feature Selector")
# Out:
# ['Feature Selector']

# %%
# Drop the 'Activity' column 
data_test=data_test.drop("Activity",axis=1)

# %%
# check the duplicated columns and convert their names into list
duplicated_columns = data_test.columns[data_test.T.duplicated()].to_list()

# %%
# Drop the duplicate columns
data_test = data_test.drop(duplicated_columns,axis=1)

# %%
# Load the "model_rfe" ,"Top K selector" and "Feature Selector"
model = joblib.load('model_rfe')
selector = joblib.load('Top K selector')
rfe_selector = joblib.load('Feature Selector')

# %%
selector=selector.transform(data_test)

# %%
# Transform the test dataset
X_test_selected_rfe = rfe_selector.transform(selector)

# %%
# Making the prediction
model.predict(X_test_selected_rfe)
# Out:
# array([2, 2, 2, ..., 5, 5, 5])
